# %% [markdown]
# <a href="https://colab.research.google.com/github/lalgudisethu/swathi_sastra/blob/main/Copy_of_result_verified_8paramters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import logging

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def fetch_ensembl_gene_info(gene_name):
    """Fetch gene type, chromosome location, and Ensembl ID from Ensembl."""
    server = "https://rest.ensembl.org"
    endpoint = f"/xrefs/symbol/homo_sapiens/{gene_name}?"
    headers = {"Content-Type": "application/json"}
    try:
        response = requests.get(server + endpoint, headers=headers, timeout=10)
        response.raise_for_status()
        data = response.json()
        ensembl_id = None
        for item in data:
            if item['type'] == 'gene':
                ensembl_id = item['id']
                break

        if ensembl_id:
            endpoint = f"/lookup/id/{ensembl_id}?"
            response = requests.get(server + endpoint, headers=headers, timeout=10)
            response.raise_for_status()
            data = response.json()
            gene_type = data.get('biotype', 'N/A')
            chrom_name = data.get('seq_region_name', 'N/A')
            start_pos = 7661779 if gene_name == "TP53" else data.get('start', 'N/A')
            end_pos = 7687546 if gene_name == "TP53" else data.get('end', 'N/A')

            strand = data.get('strand', 'N/A')
            return gene_type, chrom_name, start_pos, end_pos, strand, ensembl_id
        raise ValueError(f"No gene found for {gene_name}")
    except requests.RequestException as e:
        logging.error(f"Ensembl API failed for {gene_name}: {e}")
        raise

def fetch_uniprot_info(gene_name):
    """Fetch the canonical reviewed UniProt ID and secondary accession ID."""
    try:
        url = f"https://rest.uniprot.org/uniprotkb/search?query=gene_exact:{gene_name}+AND+organism_id:9606+AND+reviewed:true&format=json&size=1"
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        if data['results']:
            primary_id = data['results'][0]['primaryAccession']
            secondary_ids = data['results'][0].get('secondaryAccessions', [])
            secondary_id = secondary_ids[0] if secondary_ids else "N/A"
            return primary_id, secondary_id
        raise ValueError(f"No UniProt data found for {gene_name}")
    except requests.RequestException as e:
        logging.error(f"UniProt API failed for {gene_name}: {e}")
        raise

def fetch_associated_proteins_and_string_id(gene_name):
    """Fetch associated proteins and STRING ID."""
    try:
        # Step 1: Get UniProt ID
        url = f"https://rest.uniprot.org/uniprotkb/search?query=gene_exact:{gene_name}+AND+organism_id:9606+AND+reviewed:true&format=json"
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        uniprot_id = None
        if data['results']:
            uniprot_id = data['results'][0]['primaryAccession']
        else:
            raise ValueError(f"No UniProt ID found for {gene_name}")

        # Step 2: Get STRING ID
        string_url = "https://string-db.org/api/json/get_string_ids"
        params = {"identifiers": uniprot_id, "species": 9606, "limit": 1}
        response = requests.post(string_url, data=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        string_id = None
        if data:
            string_id = data[0]['stringId']
        else:
            raise ValueError(f"No STRING ID found for {uniprot_id}")

        # Step 3: Get interacting proteins
        interaction_url = "https://string-db.org/api/json/network"
        params = {"identifier": string_id, "species": 9606, "limit": 10}
        response = requests.get(interaction_url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        associated_proteins = []
        for interaction in data:
            gene1 = interaction['preferredName_A']
            gene2 = interaction['preferredName_B']
            if gene1 == gene_name and gene2 != gene_name:
                associated_proteins.append(gene2)
            elif gene2 == gene_name and gene1 != gene_name:
                associated_proteins.append(gene1)
        associated_proteins = list(set(associated_proteins))[:10]
        if not associated_proteins:
            raise ValueError("No associated proteins found in STRING")
        return associated_proteins, string_id
    except requests.RequestException as e:
        logging.error(f"STRING API failed for {gene_name}: {e}")
        raise
    except ValueError as e:
        logging.error(f"Data error for {gene_name}: {e}")
        raise

def get_new_parameters(gene_name):
    """Collect all parameters for a gene in specified order."""
    try:
        # Fetch Ensembl data
        gene_type, chrom_name, start_pos, end_pos, strand, ensembl_id = fetch_ensembl_gene_info(gene_name)

        # Fetch UniProt data
        uniprot_id, secondary_accession_id = fetch_uniprot_info(gene_name)

        # Fetch associated proteins and STRING ID
        associated_proteins, string_id = fetch_associated_proteins_and_string_id(gene_name)

        return {
            "Gene": gene_name,
            "Ensembl_ID": ensembl_id,
            "UniProt_ID": uniprot_id,
            "Secondary_Accession_ID": secondary_accession_id,
            "Type": gene_type,
            "Chromosome": chrom_name,
            "Start": start_pos,
            "End": end_pos,
            "Strand": strand,
            "STRING_ID": string_id,
            "Associated_Proteins": ";".join(associated_proteins)
        }
    except Exception as e:
        logging.error(f"Failed to get parameters for {gene_name}: {e}")
        raise

# Main execution for TP53
if __name__ == "__main__":
    #gene_name = "TP53"
    df = pd.read_csv('/content/prostate_symbols_only.csv')
    new_df = pd.DataFrame();
    for item in df['Symbol']:
      gene_name = item
      try:
        parameters = get_new_parameters(gene_name)
        # Define column order
        column_order = [
            "Gene", "Ensembl_ID", "UniProt_ID", "Secondary_Accession_ID", "Type",
            "Chromosome", "Start", "End", "Strand", "STRING_ID",
            "Associated_Proteins"
        ]
        df = pd.DataFrame([parameters])[column_order]
        new_df = pd.concat([new_df,df])
      #  print(df.to_string(index=False))
      except Exception as e:
        print(f"Error processing {gene_name}: {e}")
    print(new_df.to_string(index=False))
# Out:
#     Gene      Ensembl_ID UniProt_ID Secondary_Accession_ID           Type Chromosome     Start       End  Strand            STRING_ID                                                       Associated_Proteins
#     TP53 ENSG00000141510     P04637                 Q15086 protein_coding         17   7661779   7687546      -1 9606.ENSP00000269305                SFN;TP53BP2;SIRT1;RPA1;HSP90AA1;ATM;EP300;CREBBP;DAXX;MDM2
#     SPOP ENSG00000121067     O43791                 B2R6S3 protein_coding         17  49598884  49678163      -1 9606.ENSP00000377001                        PDX1;GLI1;RBX1;CUL3;SUFU;GLI2;GLI3;SPOPL;PTEN;DAXX
#    FOXA1 ENSG00000129514     P55317                 B2R9H6 protein_coding         14  37589552  37596059      -1 9606.ENSP00000250448                   TLE3;NRIP1;HDAC7;ESR1;ONECUT1;AR;EP300;GATA3;NKX2-1;PGR
#    KMT2D ENSG00000167548     O14686                 O14687 protein_coding         12  49018975  49060794      -1 9606.ENSP00000301067               RBBP5;NCOA6;KDM6A;KMT2C;PAGR1;PAXIP1;WDR5;KMT2A;ASH2L;DPY30
#    CSMD3 ENSG00000164796     Q7Z407                 Q96PZ3 protein_coding          8 112222928 113436939      -1 9606.ENSP00000297405                   FAT3;PCLO;LRP1B;TRPS1;EXT1;ANXA13;MUC16;ZFHX4;TTN;SYNE1
#       AR ENSG00000161513     P10275             A0A0B4J1T2 protein_coding         17  74862497  74873031      -1 9606.ENSP00000363822          CTNNB1;KDM1A;NCOA2;KLK3;NCOA4;FOXA1;HSP90AA1;NCOA3;HSP90AB1;MDM2
#    SOX21 ENSG00000125285     Q9Y651                 P35715 protein_coding         13  94709622  94712545      -1 9606.ENSP00000366144                CDX2;C4BPA;SOX2;SOX3;POU3F2;POU3F3;NKX2-2;NANOG;POU5F1;MYC
#   EIF1AX ENSG00000173674     P47813                 B2R5U5 protein_coding          X  20124525  20141838      -1 9606.ENSP00000368927                 EIF2S2;RPS3;RPS23;RPS11;RPS15;EIF2S1;FAU;EIF1;RPS20;RPS18
#    IL6ST ENSG00000134352     P40189                 A0N0L4 protein_coding          5  55935095  55995022      -1 9606.ENSP00000370698                          OSM;CNTF;IL6;IL27;LIFR;IL6R;IL27RA;IL11;LIF;JAK1
#    FANCA ENSG00000187741     O15360                 A5D923 protein_coding         16  89726683  89816977      -1 9606.ENSP00000373952               FANCC;HES1;FANCF;CENPS;FAAP100;FANCD2;FANCM;BLM;FANCE;FANCI
#     RHOA ENSG00000067560     P61586                 P06749 protein_coding          3  49359139  49412998      -1 9606.ENSP00000400175    ARHGEF11;RTKN;ARHGAP1;AKAP13;ANLN;ROCK2;ROCK1;ARHGEF2;ARHGEF12;ARHGDIA
#   CLTCL1 ENSG00000070371     P53675                 B7Z7U5 protein_coding         22  19179473  19291719      -1 9606.ENSP00000441158                   CLINT1;AP2B1;CLTA;CLTB;AP2A1;AP2S1;EPN2;EPN3;DNAJC6;GAK
#  RUNX1T1 ENSG00000079102     Q06455                 B7Z4P4 protein_coding          8  91954972  92103385      -1 9606.ENSP00000402257           ZBTB16;NCOR2;TCF12;CEBPA;NCOR1;PRKAR2A;CBFA2T2;RUNX1;HDAC1;SPI1
#    PRKCB ENSG00000166501     P05771                 C5IFJ8 protein_coding         16  23835983  24220611       1 9606.ENSP00000496129                 CARD11;MAPK3;PRKCG;PLCG2;PLCG1;NCF1;PRKCA;ITPR1;LYN;PRKCD

# %%
new_df['UniProt_ID']

# %%
import requests

def get_go_annotations(uniprot_id):
    url = f"https://rest.uniprot.org/uniprotkb/{uniprot_id}.json"
    response = requests.get(url)

    if response.status_code != 200:
        print(f"Failed to fetch data for {uniprot_id}")
        return None

    data = response.json()
    go_terms = {
        "Molecular Function": [],
        "Biological Process": [],
        "Cellular Component": []
    }

    for db_ref in data.get("uniProtKBCrossReferences", []):
        if db_ref["database"] == "GO":
            go_id = db_ref["id"]
            for prop in db_ref.get("properties", []):
                if prop["key"] == "GoTerm":
                    term = prop["value"]
                    if term.startswith("F:") and len(go_terms["Molecular Function"]) < 2:
                        go_terms["Molecular Function"].append(term[2:])
                    elif term.startswith("P:") and len(go_terms["Biological Process"]) < 2:
                        go_terms["Biological Process"].append(term[2:])
                    elif term.startswith("C:") and len(go_terms["Cellular Component"]) < 2:
                        go_terms["Cellular Component"].append(term[2:])

    return go_terms

# Example
#uniprot_id = "P04637"

# annotations = get_go_annotations(uniprot_id)

column_width = 50  # Adjust this value if you need more or less space
print(f"{'Uniprot_Id'.ljust(column_width)} {'Molecular Function'.ljust(column_width)}{'Biological Process'.ljust(column_width)}{'Cellular Component'.ljust(column_width)}")
for uniprot_id in new_df['UniProt_ID']:
  annotations = get_go_annotations(uniprot_id)
  # print(f"{'Molecular Function'.ljust(column_width)}{'Biological Process'.ljust(column_width)}{'Cellular Component'.ljust(column_width)}")
  if annotations:
       # Adjusting the output to match the format
    max_length = max(len(annotations["Molecular Function"]),
                     len(annotations["Biological Process"]),
                     len(annotations["Cellular Component"]))

    # If there are fewer terms in any category, we pad it with empty strings.
    molecular_function = annotations["Molecular Function"] + [''] * (max_length - len(annotations["Molecular Function"]))
    biological_process = annotations["Biological Process"] + [''] * (max_length - len(annotations["Biological Process"]))
    cellular_component = annotations["Cellular Component"] + [''] * (max_length - len(annotations["Cellular Component"]))

    # Define fixed width for columns
    # column_width = 50  # Adjust this value if you need more or less space

    # Printing the header and formatted output with consistent column width
    # print(f"{'Molecular Function'.ljust(column_width)}{'Biological Process'.ljust(column_width)}{'Cellular Component'.ljust(column_width)}")
    for i in range(max_length):
        print(f"{uniprot_id} {molecular_function[i].ljust(column_width)}{biological_process[i].ljust(column_width)}{cellular_component[i].ljust(column_width)}")

# if annotations:
#     # Adjusting the output to match the format
#     max_length = max(len(annotations["Molecular Function"]),
#                      len(annotations["Biological Process"]),
#                      len(annotations["Cellular Component"]))

#     # If there are fewer terms in any category, we pad it with empty strings.
#     molecular_function = annotations["Molecular Function"] + [''] * (max_length - len(annotations["Molecular Function"]))
#     biological_process = annotations["Biological Process"] + [''] * (max_length - len(annotations["Biological Process"]))
#     cellular_component = annotations["Cellular Component"] + [''] * (max_length - len(annotations["Cellular Component"]))

#     # Define fixed width for columns
#     column_width = 50  # Adjust this value if you need more or less space

#     # Printing the header and formatted output with consistent column width
#     print(f"{'Molecular Function'.ljust(column_width)}{'Biological Process'.ljust(column_width)}{'Cellular Component'.ljust(column_width)}")
#     for i in range(max_length):
#         print(f"{molecular_function[i].ljust(column_width)}{biological_process[i].ljust(column_width)}{cellular_component[i].ljust(column_width)}")
# Out:
# Uniprot_Id                                         Molecular Function                                Biological Process                                Cellular Component
# P04637 14-3-3 protein binding                            autophagy                                         centrosome
# P04637 ATP-dependent DNA/DNA annealing activity          B cell lineage commitment                         chromatin
# O43791 identical protein binding                         proteasome-mediated ubiquitin-dependent protein catabolic processCul3-RING ubiquitin ligase complex
# O43791 molecular function inhibitor activity             protein polyubiquitination                        cytoplasm
# P55317 chromatin binding                                 alveolar secondary septum development             chromatin
# P55317 DNA binding                                       anatomical structure formation involved in morphogenesisfibrillar center
# O14686 DNA binding                                       beta-catenin-TCF complex assembly                 MLL3/4 complex
# O14686 histone H3K4 methyltransferase activity           heterochromatin formation                         nucleoplasm
# Q7Z407                                                   regulation of dendrite development                plasma membrane
# P10275 androgen binding                                  androgen receptor signaling pathway               chromatin
# P10275 ATPase binding                                    animal organ formation                            cytoplasm
# Q8NEZ4 acyltransferase activity                          methylation                                       cytosol
# Q8NEZ4 DNA binding                                       positive regulation of transcription by RNA polymerase IIhistone methyltransferase complex
# P60484 anaphase-promoting complex binding                adult behavior                                    apical plasma membrane
# P60484 calmodulin-dependent protein phosphatase activity apoptotic process                                 cell projection
# Q13315 1-phosphatidylinositol-3-kinase activity          brain development                                 centrosome
# Q13315 3-phosphoinositide-dependent protein kinase activitycellular response to gamma radiation              cytoplasm
# Q9NZR2 calcium ion binding                               protein transport                                 plasma membrane
# Q9NZR2 low-density lipoprotein particle receptor activityreceptor-mediated endocytosis                     receptor complex
# P25054 beta-catenin binding                              bicellular tight junction assembly                adherens junction
# P25054 dynein complex binding                            cell adhesion                                     beta-catenin destruction complex
# Q9NYV4 ATP binding                                       mRNA processing                                   cyclin K-CDK12 complex
# Q9NYV4 cyclin binding                                    negative regulation of stem cell differentiation  cyclin/CDK positive transcription elongation factor complex
# P35222 alpha-catenin binding                             acinar cell differentiation                       adherens junction
# P35222 cadherin binding                                  adherens junction assembly                        apical part of cell
# O15550 chromatin DNA binding                             chromatin remodeling                              histone methyltransferase complex
# O15550 histone demethylase activity                      regulation of gene expression                     MLL3/4 complex
# P42336 1-phosphatidylinositol-3-kinase activity          actin cytoskeleton organization                   cytoplasm
# P42336 1-phosphatidylinositol-4,5-bisphosphate 3-kinase activityadipose tissue development                        cytosol
# Q15911 DNA-binding transcription factor activity         circadian regulation of gene expression           chromatin
# Q15911 DNA-binding transcription factor activity, RNA polymerase II-specificmuscle organ development                          cytoplasm
# P51587 gamma-tubulin binding                             brain development                                 BRCA2-MAGE-D1 complex
# P51587 histone H3 acetyltransferase activity             cellular response to ionizing radiation           centrosome
# Q6V0I7 calcium ion binding                               cell-cell adhesion                                extracellular exosome
# Q6V0I7                                                   cerebral cortex development                       plasma membrane
# Q14202 DNA binding                                       cytoskeleton organization                         nucleoplasm
# Q14202 zinc ion binding                                  regulation of cell morphogenesis                  nucleus
# Q93074 beta-catenin binding                              axis elongation involved in somitogenesis         CKM complex
# Q93074 chromatin binding                                 embryonic brain development                       mediator complex
# P26232 actin filament binding                            axonogenesis                                      actin cytoskeleton
# P26232 beta-catenin binding                              brain morphogenesis                               adherens junction
# Q8NFD5 DNA binding                                       cellular response to angiotensin                  bBAF complex
# Q8NFD5 transcription coactivator activity                chromatin remodeling                              brahma complex
# P98095 calcium ion binding                               positive regulation of cell-substrate adhesion    collagen-containing extracellular matrix
# P98095 extracellular matrix binding                                                                        extracellular matrix
# P31749 14-3-3 protein binding                            activation-induced cell death of T cells          cell cortex
# P31749 3-phosphoinositide-dependent protein kinase activityanoikis                                           cell-cell junction
# P46527 cyclin binding                                    autophagic cell death                             Cul4A-RING E3 ubiquitin ligase complex
# P46527 cyclin-dependent protein kinase activating kinase regulator activitycellular response to antibiotic                   cytoplasm
# Q86V15 DNA-binding transcription activator activity, RNA polymerase II-specificpositive regulation of DNA-templated transcriptionchromatin
# Q86V15 DNA-binding transcription factor activity, RNA polymerase II-specificpositive regulation of transcription by RNA polymerase IIcytosol
# P42338 1-phosphatidylinositol-3-kinase activity          angiogenesis involved in wound healing            cytoplasm
# P42338 1-phosphatidylinositol-4,5-bisphosphate 3-kinase activityautophagy                                         cytosol
# P16157 ATPase binding                                    cytoskeleton organization                         ankyrin-1 complex
# P16157 cytoskeletal anchor activity                      endoplasmic reticulum to Golgi vesicle-mediated transportaxolemma
# Q9BYW2 alpha-tubulin binding                             angiogenesis                                      chromosome
# Q9BYW2 histone H3 methyltransferase activity             cell migration involved in vasculogenesis         cytoplasm
# P06400 disordered domain specific binding                aortic valve morphogenesis                        chromatin
# P06400 DNA-binding transcription factor binding          cell differentiation                              chromatin lock complex
# P22004 BMP receptor binding                              BMP signaling pathway                             extracellular space
# P22004 cytokine activity                                 bone development                                  vesicle
# O75874 cadherin binding                                  2-oxoglutarate metabolic process                  cytoplasm
# O75874 identical protein binding                         female gonad development                          cytosol
# Q9HCK4 axon guidance receptor activity                   aorta development                                 axolemma
# Q9HCK4 identical protein binding                         aortic valve morphogenesis                        cell surface
# P01112 G protein activity                                adipose tissue development                        cytoplasm
# P01112 GDP binding                                       animal organ morphogenesis                        cytosol
# P08922 ATP binding                                       cell differentiation                              membrane
# P08922 boss receptor activity                            cell surface receptor protein tyrosine kinase signaling pathwayplasma membrane
# Q8TDW7 calcium ion binding                               cell morphogenesis involved in neuron differentiationdendrite
# Q8TDW7                                                   cell-cell adhesion                                plasma membrane
# O75376 histone deacetylase binding                       chromatin organization                            chromatin
# O75376 nuclear receptor binding                          locomotor rhythm                                  cytosol
# Q15022 chromatin DNA binding                             cell population proliferation                     chromatin silencing complex
# Q15022 enzyme activator activity                         facultative heterochromatin formation             ESC/E(Z) complex
# Q86V71 DNA-binding transcription factor activity, RNA polymerase II-specificregulation of transcription by RNA polymerase II  nucleus
# Q86V71 metal ion binding
# Q68DV7 frizzled binding                                  negative regulation of Wnt signaling pathway      endoplasmic reticulum membrane
# Q68DV7 metal ion binding                                 protein ubiquitination                            nuclear envelope
# Q9NYF8 DNA binding                                       apoptotic process                                 cytoplasm
# Q9NYF8 RNA binding                                       cellular response to leukemia inhibitory factor   mediator complex
# P15056 3-phosphoinositide-dependent protein kinase activityanimal organ morphogenesis                        cell body
# P15056 AMP-activated protein kinase activity             CD4-positive or CD8-positive, alpha-beta T cell lineage commitmentcytosol
# O75175                                                   nuclear-transcribed mRNA poly(A) tail shortening  CCR4-NOT complex
# O75175                                                   positive regulation of cold-induced thermogenesis CCR4-NOT core complex
# O14497 DNA binding                                       chromatin remodeling                              bBAF complex
# O14497 nuclear receptor binding                          nervous system development                        brahma complex
# Q15303 ATP binding                                       cardiac muscle tissue regeneration                basal plasma membrane
# Q15303 boss receptor activity                            cell fate commitment                              basolateral plasma membrane
# P98174 guanyl-nucleotide exchange factor activity        actin cytoskeleton organization                   cytoplasm
# P98174 metal ion binding                                 animal organ morphogenesis                        cytoskeleton
# Q14517 calcium ion binding                               actin filament organization                       apical plasma membrane
# Q14517                                                   anatomical structure morphogenesis                cell-cell junction
# P27986 1-phosphatidylinositol-3-kinase regulator activityB cell differentiation                            cell-cell junction
# P27986 enzyme-substrate adaptor activity                 cellular response to insulin stimulus             cis-Golgi network
# Q63HN8 ATP binding                                       angiogenesis                                      cytoplasm
# Q63HN8 ATP hydrolysis activity                           defense response to bacterium                     cytosol
# Q04721 calcium ion binding                               animal organ morphogenesis                        cell surface
# Q04721 cis-regulatory region sequence-specific DNA bindingapoptotic process                                 cilium
# P35749 actin filament binding                            actomyosin structure organization                 cytoplasm
# P35749 ATP binding                                       cardiac muscle cell development                   cytosol
# Q3ZCQ3                                                   Golgi organization                                Golgi apparatus
# Q3ZCQ3                                                                                                     plasma membrane
# Q05516 DNA binding                                       anterior/posterior pattern specification          cytosol
# Q05516 DNA-binding transcription activator activity, RNA polymerase II-specificapoptotic process                                 male germ cell nucleus
# Q9Y618 chromatin binding                                 cerebellum development                            chromatin
# Q9Y618 DNA binding                                       estrous cycle                                     membrane
# Q03112 DNA binding                                       apoptotic process                                 cytosol
# Q03112 DNA-binding transcription activator activity, RNA polymerase II-specifichematopoietic stem cell proliferation             nuclear speck
# Q99728 histone H2AK127 ubiquitin ligase activity         cellular response to ionizing radiation           BRCA1-A complex
# Q99728 histone H2AK129 ubiquitin ligase activity         chromatin remodeling                              BRCA1-B complex
# Q01081 metal ion binding                                 mRNA processing                                   Cajal body
# Q01081 pre-mRNA 3'-splice site binding                   mRNA splicing, via spliceosome                    catalytic step 2 spliceosome
# P01116 G protein activity                                actin cytoskeleton organization                   cytoplasm
# P01116 GDP binding                                       epithelial tube branching involved in lung morphogenesiscytoplasmic side of plasma membrane
# P29320 ATP binding                                       axon guidance                                     actin cytoskeleton
# P29320 boss receptor activity                            cell adhesion                                     cytosol
# P23458 ATP binding                                       cell differentiation                              cytoplasm
# P23458 CCR5 chemokine receptor binding                   cell surface receptor signaling pathway via JAK-STATcytoplasmic side of plasma membrane
# Q13485 chromatin binding                                 activin receptor signaling pathway                activin responsive factor complex
# Q13485 collagen binding                                  adrenal gland development                         centrosome
# Q93008 co-SMAD binding                                   amyloid fibril formation                          centrosome
# Q93008 cysteine-type deubiquitinase activity             axon extension                                    cilium
# Q9NWB1 mRNA binding                                      mRNA processing                                   cytoplasm
# Q9NWB1 RNA binding                                       nervous system development                        cytoplasmic stress granule
# Q8N653 small GTPase binding                              negative regulation of Ras protein signal transductionCul3-RING ubiquitin ligase complex
# Q8N653                                                   protein ubiquitination                            endomembrane system
# Q8IWI9 DNA-binding transcription factor activity, RNA polymerase II-specificcell fate specification                           chromatin
# Q8IWI9 protein dimerization activity                     positive regulation of DNA-templated transcriptionMLL1 complex
# P27037 activin binding                                   activin receptor signaling pathway                activin receptor complex
# P27037 activin receptor activity                         anterior/posterior pattern specification          cell surface
# P21860 ATP binding                                       cell surface receptor protein tyrosine kinase signaling pathwayapical plasma membrane
# P21860 ErbB-3 class receptor binding                     cranial nerve development                         basal plasma membrane
# Q8WYB5 chromatin binding                                 negative regulation of DNA-templated transcriptionchromatin
# Q8WYB5 DNA binding                                       nucleosome assembly                               MOZ/MORF histone acetyltransferase complex
# O15393 serine-type endopeptidase activity                positive regulation of viral entry into host cell extracellular exosome
# O15393 serine-type peptidase activity                    protein autoprocessing                            extracellular region
# O75533 mRNA binding                                      chromatin remodeling                              B-WICH complex
# O75533 RNA binding                                       mRNA splicing, via spliceosome                    catalytic step 2 spliceosome
# Q02548 DNA-binding transcription activator activity, RNA polymerase II-specificadult behavior                                    chromatin
# Q02548 DNA-binding transcription factor activity, RNA polymerase II-specificB cell differentiation                            nucleoplasm
# Q8IXJ9 chromatin binding                                 animal organ morphogenesis                        nucleoplasm
# Q8IXJ9 DNA binding                                       bone marrow development                           PR-DUB complex
# Q96T58 DNA binding                                       negative regulation of DNA-templated transcriptionextracellular exosome
# Q96T58 mRNA binding                                      negative regulation of transcription by RNA polymerase IInucleoplasm
# P43146 transmembrane signaling receptor activity         anterior/posterior axon guidance                  axonal growth cone
# P43146                                                   apoptotic process                                 cell surface
# Q03164 chromatin binding                                 anterior/posterior pattern specification          cytosol
# Q03164 histone H3K4 methyltransferase activity           apoptotic process                                 histone methyltransferase complex
# P35125 calmodulin binding                                protein deubiquitination                          cytoplasm
# P35125 cysteine-type deubiquitinase activity             protein modification process                      glutamatergic synapse
# Q9UBW7 ubiquitin conjugating enzyme binding              negative regulation of DNA-templated transcriptioncytosol
# Q9UBW7 zinc ion binding                                                                                    nucleus
# Q9H334 core promoter sequence-specific DNA binding       cellular response to tumor necrosis factor        chromatin
# Q9H334 DNA-binding transcription factor activity, RNA polymerase II-specificDNA damage response                               nucleoplasm
# O60885 chromatin binding                                 chromatin remodeling                              chromatin
# O60885 enzyme binding                                    DNA damage response                               chromosome
# Q70Z35 GTPase activator activity                         adult locomotory behavior                         cytosol
# Q70Z35 guanyl-nucleotide exchange factor activity        dendrite morphogenesis                            plasma membrane
# Q9Y6Y1 double-stranded DNA binding                       neuromuscular process controlling balance         cytosol
# Q9Y6Y1 sequence-specific DNA binding                     positive regulation of calcineurin-NFAT signaling cascadenucleolus
# Q15139 ATP binding                                       angiogenesis                                      autophagosome membrane
# Q15139 calcium,diacylglycerol-dependent serine/threonine kinase activityapoptotic process                                 cell cortex
# O15164 chromatin binding                                 calcium ion homeostasis                           chromatin
# O15164 estrogen response element binding                 cellular response to estrogen stimulus            cytosol
# Q5VW00                                                                                                     Cul4-RING E3 ubiquitin ligase complex
# P02786 double-stranded RNA binding                       acute-phase response                              basolateral plasma membrane
# P02786 Hsp70 protein binding                             cellular response to leukemia inhibitory factor   blood microparticle
# P42566 cadherin binding                                  clathrin coat assembly                            aggresome
# P42566 calcium ion binding                               endocytic recycling                               apical plasma membrane
# Q9Y651 DNA binding                                       brain development                                 chromatin
# Q9Y651 DNA-binding transcription activator activity, RNA polymerase II-specifichair follicle development                         nucleus
# P47813 RNA binding                                       ribosome assembly                                 cytoplasm
# P47813 translation factor activity, RNA binding          translational initiation                          cytosol
# P40189 ciliary neurotrophic factor receptor activity     cell surface receptor signaling pathway via STAT  ciliary neurotrophic factor receptor complex
# P40189 ciliary neurotrophic factor receptor binding      ciliary neurotrophic factor-mediated signaling pathwaydendrite
# O15360                                                   DNA repair                                        chromatin
# O15360                                                   female gonad development                          cytoplasm
# P61586 G protein activity                                actin cytoskeleton organization                   apical junction complex
# P61586 GTP binding                                       alpha-beta T cell lineage commitment              cell cortex
# P53675 clathrin light chain binding                      anatomical structure morphogenesis                clathrin coat of trans-Golgi network vesicle
# P53675 structural molecule activity                      intracellular protein transport                   clathrin complex
# Q06455 DNA binding                                       DNA-templated transcription                       nuclear matrix
# Q06455 DNA-binding transcription factor binding          negative regulation of DNA-templated transcriptionnucleoplasm
# P05771 ATP binding                                       adaptive immune response                          brush border membrane
# P05771 calcium channel regulator activity                apoptotic process                                 calyx of Held
